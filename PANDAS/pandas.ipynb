# %% [markdown]
# # PANDAS

# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name" : ["aditya","adi","tya"],
    "marks": [3204,23,235]
}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks
# 0  aditya   3204
# 1     adi     23
# 2     tya    235

# %%
df.to_csv("faltu.csc")

# %%
df.to_csv("faltu_notindex.csv",index=False)

# %% [markdown]
# **starting x rows**

# %%
df.head(2)
# Out:
#      name  marks
# 0  aditya   3204
# 1     adi     23

# %% [markdown]
# **last x rows**

# %%
df.tail(2)
# Out:
#   name  marks
# 1  adi     23
# 2  tya    235

# %% [markdown]
# **describe all numeric operation**

# %%
df.describe()
# Out:
#              marks
# count     3.000000
# mean   1154.000000
# std    1778.513705
# min      23.000000
# 25%     129.000000
# 50%     235.000000
# 75%    1719.500000
# max    3204.000000

# %% [markdown]
# **if we want to read and edite our data then we do**

# %%
ourdata=pd.read_csv("data.csv")

# %%
ourdata
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                     Level 1                99999
# 3      2019                     Level 1                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
ourdata['Year']
# Out:
# 0        2020
# 1        2020
# 2        2020
# 3        2020
# 4        2020
#          ...
# 32440    2020
# 32441    2020
# 32442    2020
# 32443    2020
# 32444    2020
# Name: Year, Length: 32445, dtype: int64

# %%
for i in range(len(ourdata["Year"])):
    ourdata["Year"][i]=2020
# Out:
# <ipython-input-48-468f3b733c29>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ourdata["Year"][i]=2020

# %%
ourdata['Year']
# Out:
# 0        2020
# 1        2020
# 2        2020
# 3        2020
# 4        2020
#          ...
# 32440    2020
# 32441    2020
# 32442    2020
# 32443    2020
# 32444    2020
# Name: Year, Length: 32445, dtype: int64

# %% [markdown]
# **TO change the index**

# %%
df.index=["first","second","third"]

# %%
df
# Out:
#           name  marks
# first   aditya   3204
# second     adi     23
# third      tya    235

# %%
df["name"]["first"]
# Out:
# 'aditya'

# %% [markdown]
# **Series it is ds of pandas in which it is one-d where there is only one type of array**

# %%
sr=pd.Series(np.random.rand(10))

# %%
print(sr,type(sr),end="\n")
# Out:
# 0    0.942524
# 1    0.928744
# 2    0.011182
# 3    0.248477
# 4    0.839040
# 5    0.132165
# 6    0.578013
# 7    0.444290
# 8    0.815346
# 9    0.518012
# dtype: float64 <class 'pandas.core.series.Series'>

# %% [markdown]
# **TO convert this pandas frames to numpy will do**

# %%
df
# Out:
#           name  marks
# first   aditya   3204
# second     adi     23
# third      tya    235

# %%
np_df=df.to_numpy()

# %%
newfile=pd.DataFrame(np_df)

# %% [markdown]
# **TO convert colum in to row or row into column we have our transpose**

# %%
df.T
# Out:
#         first second third
# name   aditya    adi   tya
# marks    3204     23   235

# %% [markdown]
# **To sort as per our requirement will do for row**

# %%
df.sort(axis=0,ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-194fd7a93475> in <module>
# ----> 1 df.sort(axis=0,ascending=False)
#
# d:\python\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5134             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5135                 return self[name]
# -> 5136             return object.__getattribute__(self, name)
#    5137
#    5138     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %% [markdown]
# **To sort as per our requirement will do for row**

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#           name  marks
# first   aditya   3204
# second     adi     23
# third      tya    235

# %%
df
# Out:
#           name  marks
# first   aditya   3204
# second     adi     23
# third      tya    235

# %%
df['name']
# Out:
# first     aditya
# second       adi
# third        tya
# Name: name, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
newdf=df

# %%
newdf
# Out:
#           name  marks
# first   aditya   3204
# second     adi     23
# third      tya    235

# %%
newdf['name']['first']="tony"
# Out:
# <ipython-input-84-4c6e5b47132a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['name']['first']="tony"

# %%
newdf
# Out:
#         name  marks
# first   tony   3204
# second   adi     23
# third    tya    235

# %%
df
# Out:
#         name  marks
# first   tony   3204
# second   adi     23
# third    tya    235

# %%
newdff=df.copy()

# %%
newdff
# Out:
#         name  marks
# first   tony   3204
# second   adi     23
# third    tya    235

# %%
newdff['name']['first']='aditya'
# Out:
# <ipython-input-89-6355c738d836>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdff['name']['first']='aditya'

# %%
newdff
# Out:
#           name  marks
# first   aditya   3204
# second     adi     23
# third      tya    235

# %%
df
# Out:
#         name  marks
# first   tony   3204
# second   adi     23
# third    tya    235

# %%
df.loc['first','name']=3

# %%
df
# Out:
#        name  marks
# first     3   3204
# second  adi     23
# third   tya    235

# %% [markdown]
# **to delete row or column**

# %%
newdff.drop('name',axis=1)
# Out:
#         marks
# first    3204
# second     23
# third     235

# %%
newdff.loc[['second','third'],['name']]
# Out:
#        name
# second  adi
# third   tya

# %%
newdff.loc[:,'name']
# Out:
# first     aditya
# second       adi
# third        tya
# Name: name, dtype: object

# %% [markdown]
# **if you want to use index from 0 to n to utilize ur time because of long names of column u can do this**

# %%
ourdata
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2020                     Level 3                 ZZ11
# 32441  2020                     Level 3                 ZZ11
# 32442  2020                     Level 3                 ZZ11
# 32443  2020                     Level 3                 ZZ11
# 32444  2020                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
ourdata.iloc[:,1]
# Out:
# 0        Level 1
# 1        Level 1
# 2        Level 1
# 3        Level 1
# 4        Level 1
#           ...
# 32440    Level 3
# 32441    Level 3
# 32442    Level 3
# 32443    Level 3
# 32444    Level 3
# Name: Industry_aggregation_NZSIOC, Length: 32445, dtype: object

# %% [markdown]
# **To delete any row or column will do this**

# %%
ourdata
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2020                     Level 3                 ZZ11
# 32441  2020                     Level 3                 ZZ11
# 32442  2020                     Level 3                 ZZ11
# 32443  2020                     Level 3                 ZZ11
# 32444  2020                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
ourdata.drop(['Year','Units'],axis=1)
# Out:
#       Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0                         Level 1                99999
# 1                         Level 1                99999
# 2                         Level 1                99999
# 3                         Level 1                99999
# 4                         Level 1                99999
# ...                           ...                  ...
# 32440                     Level 3                 ZZ11
# 32441                     Level 3                 ZZ11
# 32442                     Level 3                 ZZ11
# 32443                     Level 3                 ZZ11
# 32444                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC Variable_code  \
# 0                  All industries           H01
# 1                  All industries           H04
# 2                  All industries           H05
# 3                  All industries           H07
# 4                  All industries           H08
# ...

# %%
ourdata.drop([i for i in range(301)],axis=0)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 301    2020                     Level 4                AA141
# 302    2020                     Level 3                 AA21
# 303    2020                     Level 3                 AA21
# 304    2020                     Level 3                 AA21
# 305    2020                     Level 3                 AA21
# ...     ...                         ...                  ...
# 32440  2020                     Level 3                 ZZ11
# 32441  2020                     Level 3                 ZZ11
# 32442  2020                     Level 3                 ZZ11
# 32443  2020                     Level 3                 ZZ11
# 32444  2020                     Level 3                 ZZ11
#
#                             Industry_name_NZSIOC               Units  \
# 301    Poultry, Deer and Other Livestock Farming          Percentage
# 302                         Forestry and Logging  Dollars (millions)
# ...

# %%
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2020                     Level 3                 ZZ11
# 32441  2020                     Level 3                 ZZ11
# 32442  2020                     Level 3                 ZZ11
# 32443  2020                     Level 3                 ZZ11
# 32444  2020                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# # DARSHAN

# %%
dates=pd.to_datetime("27  june,2021")
print(type(dates))
x=pd.to_timedelta(np.arange(6),unit='d')
print(dates)
print(x)
print(x+dates)
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 2021-06-27 00:00:00
# TimedeltaIndex(['0 days', '1 days', '2 days', '3 days', '4 days', '5 days'], dtype='timedelta64[ns]', freq=None)
# DatetimeIndex(['2021-06-27', '2021-06-28', '2021-06-29', '2021-06-30',
#                '2021-07-01', '2021-07-02'],
#               dtype='datetime64[ns]', freq=None)
